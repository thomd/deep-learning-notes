# %% [markdown]
# # SciKit Learn

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Iris Dataset KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier

X, y = datasets.load_iris(as_frame=True, return_X_y=True)
data, data['target'] = X, y
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
sns.pairplot(data, hue='target');

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

classifier = KNeighborsClassifier()
classifier.fit(X_train, y_train)

classifier.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# ## Synthetic Data NN Classification

# %%
import numpy as np
X, y = datasets.make_classification(n_features=4, n_redundant=0, n_informative=4, n_classes=3)

# %%
data = pd.DataFrame(np.c_[X, y])
data
# Out:
#            0         1         2         3    4
# 0   1.457695  1.411074  2.882536 -0.059236  1.0
# 1   0.833758  0.979661  0.063355  3.037969  1.0
# 2   0.439790 -1.262232  0.951965 -1.920822  0.0
# 3  -3.047710  1.282768  2.647973 -1.196912  1.0
# 4   2.048663 -3.011032  2.913273 -0.240759  1.0
# ..       ...       ...       ...       ...  ...
# 95 -1.303641 -1.763112 -0.655060 -1.787264  2.0
# 96  0.895300 -0.414947  0.331740 -1.136981  2.0
# 97 -1.741202 -3.425953 -0.713157 -1.724312  2.0
# 98  1.041340 -0.502780  1.242578 -1.581416  2.0
# 99  1.229490 -0.755695 -1.088383 -0.202402  0.0
#
# [100 rows x 5 columns]

# %%
sns.pairplot(data, hue=4);

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

classifier = KNeighborsClassifier()
classifier.fit(X_train, y_train)

classifier.score(X_test, y_test)
# Out:
# 0.84
